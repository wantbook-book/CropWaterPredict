# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# 假设image是一个RGB图像的NumPy数组
image = cv2.imread(r'..\images\Canon\01 - Nov - 23\JPG\DSC_0537 (Pot 2) .JPG')  # 读取图像的示例代码
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
# 分离颜色通道
R, G, B = cv2.split(image)

# 计算每个通道的直方图
# 参数：图像，通道，掩码，bins，范围
hist_R = cv2.calcHist([R], [0], None, [256], [0, 256])
hist_G = cv2.calcHist([G], [0], None, [256], [0, 256])
hist_B = cv2.calcHist([B], [0], None, [256], [0, 256])

# 绘制直方图
plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.plot(hist_R, color='red')
plt.title('Red Channel')

plt.subplot(1, 3, 2)
plt.plot(hist_G, color='green')
plt.title('Green Channel')

plt.subplot(1, 3, 3)
plt.plot(hist_B, color='blue')
plt.title('Blue Channel')

plt.show()

# %%
plt.imshow(G, cmap='gray')

# %%
# 读取图像（以灰度模式）
# image = cv2.imread('your_image_path.jpg', cv2.IMREAD_GRAYSCALE)

# 假设我们已经有一个灰度图像
# image = ...

# 设置上下限阈值
lower_threshold = 140
upper_threshold = 170

# 应用cv2.inRange函数进行阈值分割
binary_image = cv2.inRange(G, lower_threshold, upper_threshold)

# 显示结果
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(binary_image, cmap='gray')
plt.title('Segmented Image')

plt.show()
